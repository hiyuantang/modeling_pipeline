# %%
import sys
sys.path.append('./src')
from torchvision import transforms
from src.utils import *

# %%
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Resize((224, 224)),   
    transforms.Normalize(mean=[0.3568, 0.3568, 0.3568], std=[0.3512, 0.3512, 0.3512]) 
    ])

synth_dir = 'E:/synth_kids_pickle/synth_rgb_False/testset.pkl'
synth_dataset = create_dataset_from_preprocessed(synth_dir, None)

print(f'The sample height is: {synth_dataset[1][1]}')
synth_dataset[1][0]
# Out:
# The sample height is: 77.0615005493164
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
kaggle_dir = 'E:/kagglehw_rgb_False/testset.pkl'
kaggle_dataset = create_dataset_from_preprocessed(kaggle_dir, None)

print(f'The sample height is: {kaggle_dataset[1][1]}')
kaggle_dataset[1][0]
# Out:
# The sample height is: 165.10000610351562
# <PIL.Image.Image image mode=RGB size=224x224>
